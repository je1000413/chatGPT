# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/ToyPJ/chatGPT'
# Out:
# /gdrive/MyDrive/ToyPJ/chatGPT

# %%
# !git init
# !git config --global user.email "je1000413"
# !git config --global user.name "je1000413"
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/ToyPJ/chatGPT/.git/

# %%
# !git remote set-url origin https://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@github.com/je1000413/chatGPT.git

# %%
# !git add .
# !git commit -m "chatGPT connection test"
# Out:
# [main a2d4390] chatGPT connection test
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite for_git_commit.ipynb (80%)

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git pull origin main
# Out:
# From https://github.com/je1000413/chatGPT
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git pull --rebase origin main
# Out:
# From https://github.com/je1000413/chatGPT
#  * branch            main       -> FETCH_HEAD
# Successfully rebased and updated refs/heads/main.
