# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/ToyPJ/chatGPT'
# Out:
# /gdrive/MyDrive/ToyPJ/chatGPT

# %%
# !git init
# !git config --global user.email "je1000413"
# !git config --global user.name "je1000413"
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/ToyPJ/chatGPT/.git/

# %%
# !git checkout -b main
# Out:
# fatal: A branch named 'main' already exists.

# %%
# !git add .
# !git commit -m "chatGPT connection test"
# Out:
# [main 312a7b5] chatGPT connection test
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git remote add origin https://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@github.com/je1000413/chatGPT.git

# !git remote set-url origin https://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@github.com/je1000413/chatGPT.git
# Out:
# error: remote origin already exists.

# %%
# !git push origin main
# Out:
# fatal: 'https//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@github.com/je1000413/chatGPT.git' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
