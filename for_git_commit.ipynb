# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/ToyPJ/chatGPT'
# Out:
# /gdrive/MyDrive/ToyPJ/chatGPT

# %%
# !git init
# !git config --global user.email "je1000413"
# !git config --global user.name "je1000413"
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/ToyPJ/chatGPT/.git/

# %%
# !git remote add origin https://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@github.com/je1000413/chatGPT.git
# Out:
# error: remote origin already exists.

# %%
# !git add .
# !git commit -m "chatGPT connection test"
# Out:
# [main 884cb2b] chatGPT connection test
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
