# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# %cd '/gdrive/MyDrive/ToyPJ/chatGPT'
# Out:
# /gdrive/MyDrive/ToyPJ/chatGPT

# %%
# !git init
# !git config --global user.email "je1000413"
# !git config --global user.name "je1000413"
# Out:
# Reinitialized existing Git repository in /gdrive/MyDrive/ToyPJ/chatGPT/.git/

# %%
# !git remote set-url origin https://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@github.com/je1000413/chatGPT.git

# %%
# !git add .
# !git commit -m "chatGPT connection test"
# Out:
# [main 7419152] chatGPT connection test
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 1.98 KiB | 155.00 KiB/s, done.
# Total 13 (delta 9), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (9/9), completed with 3 local objects.
# To https://github.com/je1000413/chatGPT.git
#    cf48e81..7419152  main -> main
